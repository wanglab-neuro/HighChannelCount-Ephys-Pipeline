# %% [markdown]
# ### Load modules

# %%
import spikeinterface as si
import spikeinterface.extractors as se 
import spikeinterface.preprocessing as spre
import spikeinterface.sorters as ss
import spikeinterface.postprocessing as spost
import spikeinterface.qualitymetrics as sqm
import spikeinterface.comparison as sc
import spikeinterface.exporters as sexp
import spikeinterface.widgets as sw

# %%
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

import warnings
warnings.simplefilter("ignore")

# %matplotlib widget

# %% [markdown]
# ### Define paths

# %%
base_folder = Path(r"D:\Vincent\Data\sc011\sc011_0106\sc011_0106_001")
file_path = r"D:\Vincent\Data\sc011\sc011_0106\sc011_0106_001\Record Node 101"

# %%
recording_saved = si.load_extractor(base_folder / "preprocessed")
print(recording_saved)
sorting = se.KiloSortSortingExtractor(base_folder / 'results_KS2_5')
print(sorting)

# %% [markdown]
# A `RecordingExtractor` object extracts information about channel ids, channel locations (if present), the sampling frequency of the recording, and the extracellular traces (when prompted).
# Here we retrieve information from the recording using the built-in functions from the RecordingExtractor:

# %% [markdown]
# ### Extract waveforms

# %%
# si.extract_waveforms?

# %%
job_kwargs = dict(n_jobs=10, chunk_duration="1s", progress_bar=True)

# %% [markdown]
# Extracts waveforms from a random subset of 500 spikes (`WaveformExtractor` default).

# %%
we = si.extract_waveforms(recording_saved, sorting, folder=base_folder / "waveforms", 
                          load_if_exists=True, overwrite=False, **job_kwargs)
print(we)
# Out:
# WaveformExtractor: 384 channels - 252 units - 1 segments
#   before:90 after:120 n_per_units:500

# %%
# w = sw.plot_unit_templates(we, radius_um=30, backend="ipywidgets")

# %%
# for unit in sorting.get_unit_ids():
#     waveforms = we.get_waveforms(unit_id=unit)
#     spiketrain = sorting.get_unit_spike_train(unit)
#     print(f"Unit {unit} - num waveforms: {waveforms.shape[0]} - num spikes: {len(spiketrain)}")

# %% [markdown]
# Extract waveforms for all spikes (use the `max_spikes_per_unit` argument).

# %%
we_all = si.extract_waveforms(recording_saved, sorting, folder=base_folder / "waveforms_all", 
                              max_spikes_per_unit=None,
                              overwrite=True,
                              **job_kwargs)
# Out:
# extract waveforms memmap:   0%|          | 0/713 [00:00<?, ?it/s]

# %%
for unit in sorting.get_unit_ids():
    waveforms = we_all.get_waveforms(unit_id=unit)
    spiketrain = sorting.get_unit_spike_train(unit)
    print(f"Unit {unit} - num waveforms: {waveforms.shape[0]} - num spikes: {len(spiketrain)}")
# Out:
# Unit 0 - num waveforms: 100 - num spikes: 100
# Unit 1 - num waveforms: 4120 - num spikes: 4120
# Unit 2 - num waveforms: 2762 - num spikes: 2762
# Unit 3 - num waveforms: 586 - num spikes: 586
# Unit 4 - num waveforms: 2205 - num spikes: 2205
# Unit 5 - num waveforms: 978 - num spikes: 978
# Unit 6 - num waveforms: 51 - num spikes: 51
# Unit 7 - num waveforms: 57731 - num spikes: 57731
# Unit 8 - num waveforms: 1028 - num spikes: 1028
# Unit 9 - num waveforms: 15530 - num spikes: 15530
# Unit 10 - num waveforms: 87 - num spikes: 87
# Unit 11 - num waveforms: 31 - num spikes: 31
# Unit 12 - num waveforms: 1492 - num spikes: 1492
# Unit 13 - num waveforms: 13648 - num spikes: 13648
# Unit 14 - num waveforms: 618 - num spikes: 618
# Unit 15 - num waveforms: 12156 - num spikes: 12156
# Unit 16 - num waveforms: 1437 - num spikes: 1437
# Unit 17 - num waveforms: 63 - num spikes: 63
# Unit 18 - num waveforms: 6146 - num spikes: 6146
# Unit 19 - num waveforms: 808 - num spikes: 808
# Unit 20 - num waveforms: 1132 - num spikes: 1132
# Unit 21 - num waveforms: 3319 - num spikes: 3319
# Unit 22 - num waveforms: 13219 - num spikes: 13219
# Unit 23 - num waveforms: 7176 - num spikes: 7176
# Unit 24 - num waveforms: 11076 - num spikes: 11076
# Unit 25 - num waveforms: 56 - num spikes: 56
# Unit 26 - num waveforms: 17260 - num spikes: 17260
# Unit 27 - num waveforms: 38 - num spikes: 38
# Unit 28 - num waveforms: 47 - num spikes: 47
# Unit 29 - num waveforms: 6842 - num spikes: 6842
# Unit 30 - num waveforms: 74 - num spikes: 74
# Unit 31 - num waveforms: 61 - num spikes: 61
# Unit 32 - num waveforms: 1489 - num spikes: 1489
# Unit 33 - num waveforms: 4750 - num spikes: 4750
# Unit 34 - num waveforms: 18 - num spikes: 18
# Unit 35 - num waveforms: 5566 - num spikes: 5566
# Unit 36 - num waveforms: 6074 - num spikes: 6074
# Unit 37 - num waveforms: 3836 - num spikes: 3836
# Unit 38 - num waveforms: 17 - num spikes: 17
# Unit 39 - num waveforms: 1334 - num spikes: 1334
# Unit 40 - num waveforms: 4507 - num spikes: 4507
# Unit 41 - num waveforms: 0 - num spikes: 0
# Unit 42 - num waveforms: 1221 - num spikes: 1221
# Unit 43 - num waveforms: 34 - num spikes: 34
# Unit 44 - num waveforms: 1919 - num spikes: 1919
# Unit 45 - num waveforms: 76 - num spikes: 76
# Unit 46 - num waveforms: 7689 - num spikes: 7689
# Unit 47 - num waveforms: 8 - num spikes: 8
# Unit 48 - num waveforms: 15 - num spikes: 15
# Unit 49 - num waveforms: 2005 - num spikes: 2005
# Unit 50 - num waveforms: 953 - num spikes: 953
# Unit 51 - num waveforms: 367 - num spikes: 367
# Unit 52 - num waveforms: 162 - num spikes: 162
# Unit 53 - num waveforms: 0 - num spikes: 0
# Unit 54 - num waveforms: 145 - num spikes: 145
# Unit 55 - num waveforms: 35 - num spikes: 35
# Unit 56 - num waveforms: 199 - num spikes: 199
# Unit 57 - num waveforms: 0 - num spikes: 0
# Unit 58 - num waveforms: 46 - num spikes: 46
# Unit 59 - num waveforms: 2060 - num spikes: 2060
# Unit 60 - num waveforms: 75 - num spikes: 75
# Unit 61 - num waveforms: 7906 - num spikes: 7906
# Unit 62 - num waveforms: 15 - num spikes: 15
# Unit 63 - num waveforms: 3322 - num spikes: 3322
# Unit 64 - num waveforms: 447 - num spikes: 447
# Unit 65 - num waveforms: 33 - num spikes: 33
# Unit 66 - num waveforms: 27 - num spikes: 27
# Unit 67 - num waveforms: 1085 - num spikes: 1085
# Unit 68 - num waveforms: 14 - num spikes: 14
# Unit 69 - num waveforms: 74 - num spikes: 74
# Unit 70 - num waveforms: 81 - num spikes: 81
# Unit 71 - num waveforms: 83 - num spikes: 83
# Unit 72 - num waveforms: 13196 - num spikes: 13196
# Unit 73 - num waveforms: 166 - num spikes: 166
# Unit 74 - num waveforms: 470 - num spikes: 470
# Unit 75 - num waveforms: 102 - num spikes: 102
# Unit 76 - num waveforms: 70 - num spikes: 70
# Unit 77 - num waveforms: 1354 - num spikes: 1354
# Unit 78 - num waveforms: 612 - num spikes: 612
# Unit 79 - num waveforms: 20 - num spikes: 20
# Unit 80 - num waveforms: 1057 - num spikes: 1057
# Unit 81 - num waveforms: 1782 - num spikes: 1782
# Unit 82 - num waveforms: 622 - num spikes: 622
# Unit 83 - num waveforms: 1373 - num spikes: 1373
# Unit 84 - num waveforms: 77 - num spikes: 77
# Unit 85 - num waveforms: 163 - num spikes: 163
# Unit 86 - num waveforms: 1399 - num spikes: 1399
# Unit 87 - num waveforms: 698 - num spikes: 698
# Unit 88 - num waveforms: 19508 - num spikes: 19508
# Unit 89 - num waveforms: 806 - num spikes: 806
# Unit 90 - num waveforms: 1044 - num spikes: 1044
# Unit 91 - num waveforms: 7223 - num spikes: 7223
# Unit 92 - num waveforms: 1641 - num spikes: 1641
# Unit 93 - num waveforms: 2175 - num spikes: 2175
# Unit 94 - num waveforms: 620 - num spikes: 620
# Unit 95 - num waveforms: 1608 - num spikes: 1608
# Unit 96 - num waveforms: 1276 - num spikes: 1276
# Unit 97 - num waveforms: 48 - num spikes: 48
# Unit 98 - num waveforms: 455 - num spikes: 455
# Unit 99 - num waveforms: 2226 - num spikes: 2226
# Unit 100 - num waveforms: 3430 - num spikes: 3430
# Unit 101 - num waveforms: 19 - num spikes: 19
# Unit 102 - num waveforms: 39 - num spikes: 39
# Unit 103 - num waveforms: 268 - num spikes: 268
# Unit 104 - num waveforms: 972 - num spikes: 972
# Unit 105 - num waveforms: 99 - num spikes: 99
# Unit 106 - num waveforms: 10 - num spikes: 10
# Unit 107 - num waveforms: 8236 - num spikes: 8236
# Unit 108 - num waveforms: 6618 - num spikes: 6618
# Unit 109 - num waveforms: 2073 - num spikes: 2073
# Unit 110 - num waveforms: 76 - num spikes: 76
# Unit 111 - num waveforms: 2529 - num spikes: 2529
# Unit 112 - num waveforms: 27 - num spikes: 27
# Unit 113 - num waveforms: 82 - num spikes: 82
# Unit 114 - num waveforms: 499 - num spikes: 499
# Unit 115 - num waveforms: 1299 - num spikes: 1299
# Unit 116 - num waveforms: 2618 - num spikes: 2618
# Unit 117 - num waveforms: 656 - num spikes: 656
# Unit 118 - num waveforms: 81 - num spikes: 81
# Unit 119 - num waveforms: 2136 - num spikes: 2136
# Unit 120 - num waveforms: 606 - num spikes: 606
# Unit 121 - num waveforms: 621 - num spikes: 621
# Unit 122 - num waveforms: 14031 - num spikes: 14031
# Unit 123 - num waveforms: 229 - num spikes: 229
# Unit 124 - num waveforms: 12259 - num spikes: 12259
# Unit 125 - num waveforms: 13110 - num spikes: 13110
# Unit 126 - num waveforms: 33 - num spikes: 33
# Unit 127 - num waveforms: 1176 - num spikes: 1176
# Unit 128 - num waveforms: 3773 - num spikes: 3773
# Unit 129 - num waveforms: 160 - num spikes: 160
# Unit 130 - num waveforms: 10254 - num spikes: 10254
# Unit 131 - num waveforms: 292 - num spikes: 292
# Unit 132 - num waveforms: 64 - num spikes: 64
# Unit 133 - num waveforms: 4362 - num spikes: 4362
# Unit 134 - num waveforms: 12717 - num spikes: 12717
# Unit 135 - num waveforms: 142 - num spikes: 142
# Unit 136 - num waveforms: 3000 - num spikes: 3000
# Unit 137 - num waveforms: 3973 - num spikes: 3973
# Unit 138 - num waveforms: 1178 - num spikes: 1178
# Unit 139 - num waveforms: 3037 - num spikes: 3037
# Unit 140 - num waveforms: 8494 - num spikes: 8494
# Unit 141 - num waveforms: 2764 - num spikes: 2764
# Unit 142 - num waveforms: 5195 - num spikes: 5195
# Unit 143 - num waveforms: 299 - num spikes: 299
# Unit 144 - num waveforms: 5390 - num spikes: 5390
# Unit 145 - num waveforms: 25643 - num spikes: 25643
# Unit 146 - num waveforms: 3785 - num spikes: 3785
# Unit 147 - num waveforms: 554 - num spikes: 554
# Unit 148 - num waveforms: 20 - num spikes: 20
# Unit 149 - num waveforms: 937 - num spikes: 937
# Unit 150 - num waveforms: 5878 - num spikes: 5878
# Unit 151 - num waveforms: 300 - num spikes: 300
# Unit 152 - num waveforms: 237 - num spikes: 237
# Unit 153 - num waveforms: 5 - num spikes: 5
# Unit 154 - num waveforms: 4394 - num spikes: 4394
# Unit 155 - num waveforms: 674 - num spikes: 674
# Unit 156 - num waveforms: 106 - num spikes: 106
# Unit 157 - num waveforms: 22 - num spikes: 22
# Unit 158 - num waveforms: 65 - num spikes: 65
# Unit 159 - num waveforms: 53 - num spikes: 53
# Unit 160 - num waveforms: 44 - num spikes: 44
# Unit 161 - num waveforms: 11 - num spikes: 11
# Unit 162 - num waveforms: 17 - num spikes: 17
# Unit 163 - num waveforms: 57 - num spikes: 57
# Unit 164 - num waveforms: 86 - num spikes: 86
# Unit 165 - num waveforms: 21 - num spikes: 21
# Unit 166 - num waveforms: 1478 - num spikes: 1478
# Unit 167 - num waveforms: 28 - num spikes: 28
# Unit 168 - num waveforms: 18 - num spikes: 18
# Unit 169 - num waveforms: 35 - num spikes: 35
# Unit 170 - num waveforms: 34 - num spikes: 34
# Unit 171 - num waveforms: 736 - num spikes: 736
# Unit 172 - num waveforms: 12983 - num spikes: 12983
# Unit 173 - num waveforms: 392 - num spikes: 392
# Unit 174 - num waveforms: 5496 - num spikes: 5496
# Unit 175 - num waveforms: 1566 - num spikes: 1566
# Unit 176 - num waveforms: 11592 - num spikes: 11592
# Unit 177 - num waveforms: 2025 - num spikes: 2025
# Unit 178 - num waveforms: 4013 - num spikes: 4013
# Unit 179 - num waveforms: 1512 - num spikes: 1512
# Unit 180 - num waveforms: 3385 - num spikes: 3385
# Unit 181 - num waveforms: 767 - num spikes: 767
# Unit 182 - num waveforms: 154 - num spikes: 154
# Unit 183 - num waveforms: 4863 - num spikes: 4863
# Unit 184 - num waveforms: 344 - num spikes: 344
# Unit 185 - num waveforms: 4733 - num spikes: 4733
# Unit 186 - num waveforms: 4428 - num spikes: 4428
# Unit 187 - num waveforms: 41 - num spikes: 41
# Unit 188 - num waveforms: 18 - num spikes: 18
# Unit 189 - num waveforms: 10894 - num spikes: 10894
# Unit 190 - num waveforms: 5005 - num spikes: 5005
# Unit 191 - num waveforms: 5080 - num spikes: 5080
# Unit 192 - num waveforms: 826 - num spikes: 826
# Unit 193 - num waveforms: 768 - num spikes: 768
# Unit 194 - num waveforms: 14 - num spikes: 14
# Unit 195 - num waveforms: 4270 - num spikes: 4270
# Unit 196 - num waveforms: 1705 - num spikes: 1705
# Unit 197 - num waveforms: 2232 - num spikes: 2232
# Unit 198 - num waveforms: 31 - num spikes: 31
# Unit 199 - num waveforms: 84 - num spikes: 84
# Unit 200 - num waveforms: 2573 - num spikes: 2573
# Unit 201 - num waveforms: 17 - num spikes: 17
# Unit 202 - num waveforms: 502 - num spikes: 502
# Unit 203 - num waveforms: 505 - num spikes: 505
# Unit 204 - num waveforms: 5799 - num spikes: 5799
# Unit 205 - num waveforms: 27 - num spikes: 27
# Unit 206 - num waveforms: 852 - num spikes: 852
# Unit 207 - num waveforms: 615 - num spikes: 615
# Unit 208 - num waveforms: 61 - num spikes: 61
# Unit 209 - num waveforms: 211 - num spikes: 211
# Unit 210 - num waveforms: 736 - num spikes: 736
# Unit 211 - num waveforms: 31 - num spikes: 31
# Unit 212 - num waveforms: 15413 - num spikes: 15413
# Unit 213 - num waveforms: 56 - num spikes: 56
# Unit 214 - num waveforms: 743 - num spikes: 743
# Unit 215 - num waveforms: 331 - num spikes: 331
# Unit 216 - num waveforms: 1028 - num spikes: 1028
# Unit 217 - num waveforms: 17 - num spikes: 17
# Unit 218 - num waveforms: 588 - num spikes: 588
# Unit 219 - num waveforms: 265 - num spikes: 265
# Unit 220 - num waveforms: 88 - num spikes: 88
# Unit 221 - num waveforms: 1380 - num spikes: 1380
# Unit 222 - num waveforms: 38 - num spikes: 38
# Unit 223 - num waveforms: 597 - num spikes: 597
# Unit 224 - num waveforms: 2700 - num spikes: 2700
# Unit 225 - num waveforms: 545 - num spikes: 545
# Unit 226 - num waveforms: 332 - num spikes: 332
# Unit 227 - num waveforms: 129 - num spikes: 129
# Unit 228 - num waveforms: 5216 - num spikes: 5216
# Unit 229 - num waveforms: 80 - num spikes: 80
# Unit 230 - num waveforms: 4900 - num spikes: 4900
# Unit 231 - num waveforms: 1227 - num spikes: 1227
# Unit 232 - num waveforms: 2971 - num spikes: 2971
# Unit 233 - num waveforms: 355 - num spikes: 355
# Unit 234 - num waveforms: 230 - num spikes: 230
# Unit 235 - num waveforms: 1664 - num spikes: 1664
# Unit 236 - num waveforms: 2374 - num spikes: 2374
# Unit 237 - num waveforms: 2757 - num spikes: 2757
# Unit 238 - num waveforms: 31 - num spikes: 31
# Unit 239 - num waveforms: 2418 - num spikes: 2418
# Unit 240 - num waveforms: 40 - num spikes: 40
# Unit 241 - num waveforms: 1889 - num spikes: 1889
# Unit 242 - num waveforms: 82 - num spikes: 82
# Unit 243 - num waveforms: 1513 - num spikes: 1513
# Unit 244 - num waveforms: 373 - num spikes: 373
# Unit 245 - num waveforms: 18 - num spikes: 18
# Unit 246 - num waveforms: 253 - num spikes: 253
# Unit 247 - num waveforms: 513 - num spikes: 513
# Unit 248 - num waveforms: 106 - num spikes: 106
# Unit 249 - num waveforms: 1188 - num spikes: 1188
# Unit 250 - num waveforms: 469 - num spikes: 469
# Unit 251 - num waveforms: 3835 - num spikes: 3835
# Unit 252 - num waveforms: 3899 - num spikes: 3899
# Unit 253 - num waveforms: 916 - num spikes: 916
# Unit 254 - num waveforms: 1254 - num spikes: 1254

# %%
we_KS = si.WaveformExtractor.create(recording_saved, sorting, 'waveforms', remove_if_exists=True)
we_KS.set_params(ms_before=3., ms_after=4., max_spikes_per_unit=500)
we_KS.run_extract_waveforms(n_jobs=-1, chunk_size=30000)
print(we_KS)
# Out:
# extract waveforms memmap:   0%|          | 0/713 [00:00<?, ?it/s]
# WaveformExtractor: 384 channels - 255 units - 1 segments
#   before:90 after:120 n_per_units:500

# %% [markdown]
# ### Postprocessing

# %% [markdown]
# #### Sparsity
#
# Especially when working with silicon high-density probes, or when our probe has multiple groups (e.g. multi-shank, tetrodes), we don't care about waveform/templates on all channels. In order to find a subset of channels for each unit, we can use the `get_template_channel_sparsity()`

# %%
# spost.get_template_channel_sparsity?

# %%
from spikeinterface import compute_sparsity

# %%
# example: radius
# sparsity_radius = spost.get_template_channel_sparsity(we, method="radius", radius_um=50)
sparsity_radius = compute_sparsity(we, method="radius", radius_um=50)
print(sparsity_radius)
# Out:
# ChannelSparsity - units: 252 - channels: 384 - ratio: 0.02

# %%
# example: best
# sparsity_best = spost.get_template_channel_sparsity(we, method="best_channels", num_channels=4)
sparsity_best = compute_sparsity(we, method="best_channels", num_channels=4)
print(sparsity_best)
# Out:
# ChannelSparsity - units: 252 - channels: 384 - ratio: 0.01

# %% [markdown]
# Most of the plotting and exporting functions accept `sparsity` as an argument.

# %%
# sw.plot_unit_templates(we, sparsity=sparsity_radius, backend="ipywidgets")

# %%
# sw.plot_unit_templates(we, sparsity=sparsity_best, backend="ipywidgets")

# %% [markdown]
# ### PCA scores
#
# PCA scores can be easily computed with the `compute_principal_components()` function. Similarly to the `extract_waveforms`, the function returns an object of type `WaveformPrincipalComponent` that allows to retrieve all pc scores on demand.

# %%
# spost.compute_principal_components?

# %%
print(sparsity_radius)
# Out:
# ChannelSparsity - units: 252 - channels: 384 - ratio: 0.02

# %%
pc = spost.compute_principal_components(we, n_components=3,
                                        sparsity=sparsity_radius, 
                                        load_if_exists=False,
                                        n_jobs=job_kwargs["n_jobs"], 
                                        progress_bar=job_kwargs["progress_bar"])
# Out:
# Fitting PCA:   0%|          | 0/252 [00:00<?, ?it/s]
# Projecting waveforms:   0%|          | 0/252 [00:00<?, ?it/s]

# %%
pc0 = pc.get_projections(unit_id=0)
print(f"PC scores shape: {pc0.shape}")
all_labels, all_pcs = pc.get_all_projections()
print(f"All PC scores shape: {all_pcs.shape}")
# Out:
# PC scores shape: (100, 3, 384)
# All PC scores shape: (84946, 3, 384)

# %% [markdown]
# For pc scores of a single unit, the dimension is (num_spikes, num_components, num_channels).

# %% [markdown]
# ## WaveformExtensions
#
# When we compute PCA (or use other postprocessing functions), the computed information is added to the waveform folder. The functions act as `WaveformExtensions`:

# %%
we.get_available_extension_names()
# Out:
# ['template_metrics',
#  'similarity',
#  'principal_components',
#  'spike_amplitudes',
#  'correlograms',
#  'spike_locations',
#  'unit_locations',
#  'quality_metrics']

# %% [markdown]
# Each `WaveformExtension` is an object that allows us to retrieve the data:

# %%
pc = we.load_extension("principal_components")
print(pc)
# Out:
# WaveformPrincipalComponent: 384 channels - 1 segments
#   mode: by_channel_local n_components: 3 - sparse

# %%
all_labels, all_pcs = pc.get_data()
print(all_pcs.shape)
# Out:
# (84946, 3, 384)

# %% [markdown]
# ### Spike amplitudes

# %% [markdown]
# Spike amplitudes can be computed with the `get_spike_amplitudes` function.

# %%
amplitudes = spost.compute_spike_amplitudes(we, outputs="by_unit", load_if_exists=True, 
                                            **job_kwargs)

# %% [markdown]
# By default, all amplitudes are concatenated in one array with all amplitudes form all spikes. With the `output="by_unit"` argument, instead, a dictionary is returned:

# %%
amplitudes[0]
# Out:
# {0: array([-59.329224, -86.951965, -69.41298 , -66.68459 , -69.58998 ,
#         -69.062325, -44.64085 , -78.12652 , -75.40594 , -66.01581 ,
#         -66.59062 , -77.278046, -45.41994 , -87.838875, -81.34638 ,
#         -49.149414, -90.72847 , -57.381588, -61.831345, -70.35241 ,
#         -37.907978, -59.72202 , -83.671295, -70.822235, -69.369865,
#         -75.37647 , -64.431435, -42.243298, -73.74475 , -56.38531 ,
#         -50.877014, -25.92337 , -71.94904 , -71.49883 , -62.23607 ,
#         -77.28405 , -70.38199 , -68.14468 , -45.26394 , -43.810593,
#         -29.263493, -49.511276, -38.211933, -47.412796, -66.76882 ,
#         -61.59304 , -52.80741 , -79.04591 , -49.89466 , -64.09306 ,
#         -40.185425, -52.4434  , -77.65495 , -54.893814, -70.382774,
#         -75.63662 , -53.603996, -71.49326 , -47.18581 , -66.32992 ,
#         -71.66963 , -57.32662 , -60.982105, -50.154976, -71.33039 ,
#         -81.73359 , -39.969185, -29.938917, -51.807705, -22.383068,
#         -61.981506, -46.41142 , -28.987514, -37.74013 , -52.678707,
#         -88.15693 , -61.73868 , -73.85702 , -59.17248 , -56.42005 ,
#         -53.42401 , -22.79218 , -59.644985, -69.66724 , -40.620003,
#         -71.66457 , -45.82673 , -76.491005, -74.1197  , -58.160606,
#         -55.705406, -66.02744 , -73.85887 , -78.65342 , -51.18238 ,
#         -51.220467, -36.584545, -54.27458 , -36.75066 , -51.17412 ,
#         -50.95294 , -61.936016, -58.93823 , -46.35038 , -37.136745,
#         -59.28121 , -59.679268, -64.8245  , -54.093456, -61.244713,
#         -44.453735, -73.27341 , -52.77126 , -48.78993 , -53.554695,
#         -47.774475, -38.80416 , -34.423443, -64.91225 , -33.25637 ,
#         -58.61271 , -51.655884, -61.764492, -72.7022  , -59.170322,
#         -43.614956, -72.317   , -41.99022 , -46.969933, -53.50998 ,
#         -59.33731 , -66.0139  , -53.22672 , -53.819153, -56.734993,
#         -57.744164, -51.785103, -52.27512 , -74.0894  , -62.00707 ,
#         -32.40627 , -44.659916, -48.600376, -58.454258, -57.835815,
#         -45.714878, -66.954865, -40.680878, -41.49109 , -49.826035,
#         -51.401863, -54.452595, -41.467323, -58.09278 , -60.636   ,
#         -44.802574, -53.008137, -43.993397, -48.328075, -40.156147,
#         -47.770798, -39.9396  , -66.284065, -59.23713 , -48.927223,
#         -51.793926], dtype=float32),
#  254: array([-10.207892,  -6.813709, -28.685099, ..., -49.6528  , -35.654903,
#         -40.10422 ], dtype=float32)}

# %%
# sw.plot_amplitudes(we, backend="ipywidgets")

# %% [markdown]
# ### Compute unit and spike locations
#
# When using silicon probes, we can estimate the unit (or spike) location with triangulation. This can be done either with a simple center of mass or by assuming a monopolar model:
#
# $$V_{ext}(\boldsymbol{r_{ext}}) = \frac{I_n}{4 \pi \sigma |\boldsymbol{r_{ext}} - \boldsymbol{r_{n}}|}$$
#
# where $\boldsymbol{r_{n}}$ is the position of the neuron, and $\boldsymbol{r_{n}}$ of the electrode(s).

# %%
unit_locations = spost.compute_unit_locations(we, method="monopolar_triangulation", load_if_exists=True)
spike_locations = spost.compute_spike_locations(we, method="center_of_mass", load_if_exists=True,
                                                **job_kwargs)

# %%
# sw.plot_unit_locations(we, backend="ipywidgets")

# %%
# sw.plot_spike_locations(we, max_spikes_per_unit=300, backend="ipywidgets")

# %% [markdown]
# ### Compute correlograms

# %%
ccgs, bins = spost.compute_correlograms(we)

# %%
# sw.plot_autocorrelograms(we, unit_ids=sorting.unit_ids[:3])
# sw.plot_crosscorrelograms(we, unit_ids=sorting.unit_ids[:3])

# %% [markdown]
# ### Compute template similarity

# %%
similarity = spost.compute_template_similarity(we)

# %% [markdown]
# ### Compute template metrics
#
# Template metrics, or extracellular features, such as peak to valley duration or full-width half maximum, are important to classify neurons into putative classes (excitatory - inhibitory). The `postprocessing` allows one to compute several of these metrics:

# %%
print(spost.get_template_metric_names())
# Out:
# ['peak_to_valley', 'peak_trough_ratio', 'half_width', 'repolarization_slope', 'recovery_slope']

# %%
template_metrics = spost.calculate_template_metrics(we)
display(template_metrics)
# Out:
#     peak_to_valley peak_trough_ratio half_width repolarization_slope  \
# 0         0.000293         -0.554656   0.000197        469169.283462
# 1          0.00036         -0.211997   0.000207        377229.949645
# 2         0.000323         -0.484906    0.00016          593648.0388
# 3         0.000133         -0.679876     0.0001       7257964.007012
# 4          0.00042          -0.55181   0.000237        532783.294182
# ..             ...               ...        ...                  ...
# 250       0.000197         -0.371662    0.00012       1119072.083715
# 251       0.000443         -0.444956   0.000173        409619.027693
# 252       0.000153         -0.701695   0.000103       2919791.807888
# 253       0.000633         -0.187739   0.000163        223063.857447
# 254        0.00065         -0.176355   0.000157        159984.779193
#
#     recovery_slope
# 0    -52823.757632
# 1    -26599.570886
# 2     -64672.64749
# 3   -392783.036152
# 4   -103368.374543
# ..             ...
# 250  -71912.758016
# 251  -65846.267262
# 252 -199895.883616
# 253  -15062.692726
# 254  -10981.915874
#
# [252 rows x 5 columns]

# %%
# sw.plot_template_metrics(we, include_metrics=["peak_to_valley", "half_width"], 
#                          backend="ipywidgets")
# Out:
# AppLayout(children=(VBox(children=(Label(value='units:'), SelectMultiple(layout=Layout(height='10cm', width='3…

# %% [markdown]
# For more information about these template metrics, we refer to this [documentation](https://github.com/AllenInstitute/ecephys_spike_sorting/tree/master/ecephys_spike_sorting/modules/mean_waveforms) from the Allen Institute.

# %% [markdown]
# # 7. Quality metrics and curation <a class="anchor" id="curation"></a>
#
# The `qualitymetrics` module also provides several functions to compute qualitity metrics to validate the spike sorting results.
#
# Let's see what metrics are available:

# %%
print(sqm.get_quality_metric_list())
print(sqm.get_quality_pca_metric_list())
# Out:
# ['num_spikes', 'firing_rate', 'presence_ratio', 'snr', 'isi_violations', 'rp_violations', 'amplitude_cutoff']
# ['isolation_distance', 'l_ratio', 'd_prime', 'nearest_neighbor', 'nn_isolation', 'nn_noise_overlap']

# %%
from spikeinterface.qualitymetrics import compute_quality_metrics

# %%
# qm = sqm.compute_quality_metrics(we, sparsity=sparsity_radius, verbose=True, 
#                                  n_jobs=job_kwargs["n_jobs"])
qm = compute_quality_metrics(we, sparsity=sparsity_radius, verbose=True, 
                                 n_jobs=job_kwargs["n_jobs"])
# qm = si.compute_quality_metrics(we, metric_names=['snr', 'isi_violation', 'amplitude_cutoff'])
# metrics = si.compute_quality_metrics(we_KS, metric_names=['snr', 'isi_violation', 'amplitude_cutoff'])
# Out:
# Computing num_spikes
# Computing firing_rate
# Computing presence_ratio
# Computing snr
# Computing isi_violations
# Computing rp_violations
# Computing amplitude_cutoff
# Computing PCA metrics:   0%|          | 0/252 [00:00<?, ?it/s]

# %%
display(qm)
# Out:
#      num_spikes  firing_rate  presence_ratio        snr  isi_violations_ratio  \
# 0           100     0.140363        1.000000   4.579777              0.000000
# 1          4120     5.782940        1.000000   5.266185              0.000000
# 2          2762     3.876816        1.000000   5.323824              0.000000
# 3           586     0.822525        0.818182  33.317558              8.990325
# 4          2205     3.094996        1.000000   9.597290              0.000000
# ..          ...          ...             ...        ...                   ...
# 250         469     0.658301        1.000000   6.067339              2.159293
# 251        3835     5.382906        1.000000   7.311440              0.016147
# 252        3899     5.472738        0.545455  17.996609              0.000000
# 253         916     1.285722        0.909091   6.600979              0.566065
# 254        1254     1.760147        1.000000   4.672559              0.000000
#
#      isi_violations_count  rp_contamination  rp_violations  amplitude_cutoff  \
# 0                       0          0.000000              0               NaN
# 1                       0          0.000000              0          0.000375
# 2                       0          0.000000              0          0.001206
# 3                      13          1.000000              2          0.001141
# 4                       0          0.000000              0          0.000771
# ..                    ...               ...            ...               ...
# 250                     2          1.000000              1               NaN
# 251                     1          0.024521              1          0.002072
# 252                     0          0.000000              0          0.002074
# 253                     2          1.000000              2          0.000984
# 254                     0          0.000000              0          0.006868
#
#      isolation_distance   l_ratio    d_prime  nn_hit_rate  nn_miss_rate
# 0             98.494005  0.000110  -6.948646     0.952500      0.000000
# 1             84.630560  0.000719  -5.969864     0.982500      0.001278
# 2            773.881318  0.298357  -2.826627     0.772500      0.161000
# 3            475.574833  0.082893  -5.334323     0.917000      0.021388
# 4            236.035645  0.000000 -10.938807     0.995000      0.001637
# ..                  ...       ...        ...          ...           ...
# 250           29.596832  0.460845  -3.219254     0.703625      0.043036
# 251           37.198577  0.287017   3.779772     0.763000      0.008949
# 252          100.953435  0.068867  -3.913120     0.830500      0.071262
# 253           40.831974  0.079904   4.591321     0.780000      0.027922
# 254           24.049049  0.548554   2.887397     0.660000      0.016789
#
# [252 rows x 14 columns]

# %%
# sw.plot_quality_metrics(we, include_metrics=["amplitude_cutoff", "presence_ratio", "isi_violations_ratio", "snr"], 
#                         backend="ipywidgets")

# %% [markdown]
# For more information about these waveform features, we refer to the [SpikeInterface documentation](https://spikeinterface.readthedocs.io/en/latest/module_qualitymetrics.html) and to this excellent [documentation](https://allensdk.readthedocs.io/en/latest/_static/examples/nb/ecephys_quality_metrics.html) from the Allen Institute.

# %% [markdown]
# ## Automatic curation based on quality metrics

# %% [markdown]
# A viable option to curate (or at least pre-curate) a spike sorting output is to filter units based on quality metrics. As we have already computed quality metrics a few lines above, we can simply filter the `qm` dataframe based on some thresholds.
#
# Here, we'll only keep units with an ISI violation threshold < 0.2 and amplitude cutoff < 0.9:

# %%
isi_viol_thresh = 0.2
amp_cutoff_thresh = 0.1

# %% [markdown]
# A straightforward way to filter a pandas dataframe is via the `query`.
# We first define our query (make sure the names match the column names of the dataframe):

# %%
our_query = f"amplitude_cutoff < {amp_cutoff_thresh} & isi_violations_ratio < {isi_viol_thresh}"
print(our_query)
# Out:
# amplitude_cutoff < 0.1 & isi_violations_ratio < 0.2

# %% [markdown]
# and then we can use the query to select units:

# %%
keep_units = qm.query(our_query)
keep_unit_ids = keep_units.index.values

# %%
sorting_auto_KS25 = sorting.select_units(keep_unit_ids)
print(f"Number of units before curation: {len(sorting.get_unit_ids())}")
print(f"Number of units after curation: {len(sorting_auto_KS25.get_unit_ids())}")
# Out:
# Number of units before curation: 255
# Number of units after curation: 107

# %% [markdown]
# We can also save all the waveforms and post-processed data for curated units in a separate folder:

# %%
we_curated = we.select_units(keep_unit_ids, new_folder=base_folder / "waveforms_curated")

# %%
print(we_curated)
# Out:
# WaveformExtractor: 384 channels - 107 units - 1 segments
#   before:90 after:120 n_per_units:500

# %%
we_curated.get_available_extension_names()
# Out:
# ['template_metrics',
#  'similarity',
#  'principal_components',
#  'spike_amplitudes',
#  'correlograms',
#  'spike_locations',
#  'unit_locations',
#  'quality_metrics']

# %% [markdown]
# ### Viewers

# %% [markdown]
# #### SpikeInterface GUI
#
# A QT-based GUI built on top of SpikeInterface objects.
#
# Developed by Samuel Garcia, CRNL, Lyon.

# %%
#!sigui waveforms/

# %% [markdown]
# #### Sorting Summary - SortingView

# %% [markdown]
# The `sortingview` backend requires an additional step to configure the transfer of the data to be plotted to the cloud.
#
# See documentation [here](https://spikeinterface.readthedocs.io/en/latest/module_widgets.html).
#
# Developed by Jeremy Magland and Jeff Soules, Flatiron Institute, NYC

# %%
w = sw.plot_sorting_summary(we_curated, sparsity=sparsity_radius, backend="sortingview")

# %%
w.view

# %% [markdown]
# ### Exporters

# %% [markdown]
# #### Export to Phy for manual curation
#
# To perform manual curation we can export the data to [Phy](https://github.com/cortex-lab/phy).

# %%
sexp.export_to_phy?

# %%
# sexp.export_to_phy(we, output_folder=base_folder / 'phy_KS25', 
#                    compute_amplitudes=False, compute_pc_features=False, copy_binary=True,
#                    **job_kwargs) 
sparsity_radius = compute_sparsity(we_curated, method="radius", radius_um=50)
sexp.export_to_phy(we_curated, output_folder=base_folder / 'phy_KS25', 
                   compute_amplitudes=False, compute_pc_features=False, copy_binary=True, sparsity=sparsity_radius,
                   **job_kwargs) 
# sparsity_best = compute_sparsity(we_curated, method="best_channels", num_channels=4)
# sexp.export_to_phy(we_curated, output_folder=base_folder / 'phy_KS25', 
#                    compute_amplitudes=False, compute_pc_features=False, copy_binary=True, sparsity=sparsity_best,
#                    **job_kwargs)
# Out:
# WARNING: export to Phy with many channels and without sparsity might result in a heavy and less informative visualization. You can use use a sparse WaveformExtractor or you can use the 'sparsity' argument to enforce sparsity (see compute_sparsity())
# write_binary_recording with n_jobs = 10 and chunk_size = 30000
# write_binary_recording:   0%|          | 0/713 [00:00<?, ?it/s]
# Run:
# phy template-gui  D:\Vincent\Data\sc011\sc011_0106\sc011_0106_001\phy_KS25\params.py

# %% [markdown]
# There is a problem with the latest version of Phy so we need to set an environment variable to make it work properly:
#
# - Python:
# ```
# import os
# os.environ["QTWEBENGINE_CHROMIUM_FLAGS"] = "--single-process"
# ```
#
# - OR terminal:
#
#   - Linux/MacOS:
# `export QTWEBENGINE_CHROMIUM_FLAGS="--single-process"`
#
#   - Windows:
# `set QTWEBENGINE_CHROMIUM_FLAGS="--single-process"`
#
# Then we can run the Phy GUI:

# %%
import os
os.environ["QTWEBENGINE_CHROMIUM_FLAGS"] = "--single-process"

# %%
# %%capture --no-display
# !phy template-gui phy_KS25/params.py

# %% [markdown]
# After curating the results we can reload it using the `PhySortingExtractor` and exclude the units that we labeled as `noise`:

# %%
sorting_phy_curated = se.PhySortingExtractor(base_folder / 'phy_KS25/', exclude_cluster_groups=['noise'])

# %%
print(f"Number of units before curation: {len(sorting.get_unit_ids())}")
print(f"Number of units after curation: {len(sorting_phy_curated.get_unit_ids())}")
